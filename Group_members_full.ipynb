# %%
import requests
import pandas as pd

token = open('C:/Users/USER/Documents/token.txt', 'r').read()

owner_id = input()

def get_members(owner_id):
    from collections import defaultdict
    s = defaultdict(list)
    r = requests.post('https://api.vk.com/method/execute.groupMembers?group_id='+
                      str(owner_id)+'&offset='+str(0)+'&v='+'5.73'+'&count='+str(5000)
                      +'&access_token='+token).json()['response']
    ##################################################################################
    members_count = r[0] #количество участников
    print('В сообществе', owner_id, 'участников :',members_count)
    for k,v in r[1][0].items():
        s[k].extend(v)
    
    if members_count>5000:
        for offset in range(5000, members_count, 5000):
            try:
                count = offset + 5000
                r = requests.post('https://api.vk.com/method/execute.groupMembers?group_id='+
                                 str(owner_id)+'&offset='+str(offset)+'&v='+'5.73'+'&count='+
                                 str(count)+'&access_token='+token).json()['response'][1][0]
                for k,v in r.items():
                    s[k].extend(v)
            except Exception:
                pass
            
    return s

result = get_members(owner_id)
df_1 = pd.DataFrame.from_dict(result)

def write_excel(df):
    #Функция для записи датафрейма в эксель
    try:
        writer = pd.ExcelWriter('{}.xlsx'.format(input('Input file_name: ')))
        df.to_excel(writer,'Sheet1')
        writer.save()
        print('Файл записан')
    except Exception as e:
        print(str(e))
        
write_excel(df_1)
# Out:
# 29062072
# В сообществе 29062072 участников : 5744
# Input file_name: chernosotnya
# Файл записан

# %%
import requests
import pandas as pd
import re

token = open('C:/Users/USER/Documents/token.txt', 'r').read()

ids = open('C:/Users/USER/Documents/магистерская/практическая часть/ids.txt', 'r').read().split(',')

def get_members(owner_id):
    from collections import defaultdict
    s = defaultdict(list)
    try:
        r = requests.post('https://api.vk.com/method/execute.groupMembers?group_id='+
                          str(owner_id)+'&offset='+str(0)+'&v='+'5.73'+'&count='+str(5000)
                          +'&access_token='+token).json()['response']
        ##################################################################################

        members_count = r[0] #количество участников
        print('В сообществе', owner_id, 'участников :',members_count)
        for k,v in r[1][0].items():
            s[k].extend(v)

        if members_count>5000:
            for offset in range(5000, members_count, 5000):
                try:
                    count = offset + 5000
                    r = requests.post('https://api.vk.com/method/execute.groupMembers?group_id='+
                                     str(owner_id)+'&offset='+str(offset)+'&v='+'5.73'+'&count='+
                                     str(count)+'&access_token='+token).json()['response'][1][0]
                    for k,v in r.items():
                        s[k].extend(v)
                except Exception:
                    pass

        df = pd.DataFrame.from_dict(s)

        try:
            screen_name = requests.get('https://api.vk.com/method/groups.getById',
                                        params={'group_id':str(gid),
                            'access_token':token, 'v':'5.73'}).json()['response'][-1]['name']
            screen_name =re.sub('[^\w_.)( -]', '', screen_name)
            writer = pd.ExcelWriter('C:/Users/USER/Documents/магистерская/практическая часть/{}.xlsx'.format(screen_name))
            df.to_excel(writer,'Sheet1')
            writer.save()
            print('Файл записан')
        except Exception as e:
            print(str(e))
            
    except Exception as e:
        pass

        
for gid in ids[1:]:
    get_members(gid)
# Out:
# В сообществе 71143553 участников : 1355
# Файл записан
# В сообществе 117212348 участников : 439
# Файл записан
# В сообществе 86369815 участников : 266
# Файл записан
# В сообществе 29062072 участников : 5744
# Файл записан
# В сообществе 23219128 участников : 6861
# Файл записан
# В сообществе 87541481 участников : 452
# Файл записан
# В сообществе 139246969 участников : 13060
# Файл записан
# В сообществе 21239875 участников : 297558
# C:\ProgramData\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 
л%20на%20неё,%20чем%20это%20было%20определено%20нашими%20наследственными%20задатками,%20то%20есть%20за%20время%20нашей%20жизни%20пройти%20некий%20путь%20духовного%20усовершенствования.%20(Сумма%20таких%20процессов%20только%20и%20может%20назваться%20духовным%20прогрессом%20человечества.)%20Если%20так,%20то%20внешняя%20свобода%20оказывается%20не%20самодовлеющей%20целью%20людей%20и%20обществ,%20а%20лишь%20пособным%20средством%20нашего%20неискажённого%20развития;%20только%20возможностью%20для%20нас%20—%20прожить%20не%20животным,%20а%20человеческим%20существом;%20только%20условием,%20чтобы%20человек%20лучше%20выполнил%20своё%20земное%20назначение.%20И%20свобода%20—%20не%20единственное%20такое%20условие.%20Никак%20не%20меньше%20внешней%20свободы%20нуждается%20человек%20—%20в%20незагрязнённом%20просторе%20для%20души,%20в%20возможностях%20душевного%20сосредоточения.%20%20Увы,%20современная%20цивилизованная%20свобода%20именно%20этого%20простора%20не%20хочет%20оставить%20нам.%20Увы,%20именно%20за%20последние%20десятилетия%20само%20наше%20представление%20о%20свободе%20снизилось%20и%20измельчилось%20по%20сравнению%20с%20предыдущими%20веками,%20оно%20свелось%20почти%20исключительно%20к%20свободе%20от%20наружного%20давления,%20к%20свободе%20от%20государственного%20насилия.%20К%20свободе,%20понятой%20всего%20лишь%20на%20юридическом%20уровне%20—%20и%20не%20выше.%20%20Свобода!%20—%20принудительно%20засорять%20коммерческим%20мусором%20почтовые%20ящики,%20глаза,%20уши,%20мозги%20людей,%20телевизионные%20передачи,%20так%20чтоб%20ни%20одну%20нельзя%20было%20посмотреть%20со%20связным%20смыслом.%20Свобода!%20—%20навязывать%20информацию,%20не%20считаяс ...
#   force_unicode(url))
# Файл записан
# В сообществе 47394483 участников : 5741
# Файл записан
# В сообществе 69469403 участников : 513
# Файл записан
# В сообществе 64024736 участников : 1561
# Файл записан
# В сообществе 31566932 участников : 2548
# Файл записан
# В сообществе 23477308 участников : 31827
# C:\ProgramData\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://www.google.com.ua/imgres?imgurl=http%3A%2F%2Fpsyradio.com.ua%2Ffiles%2Fphoto%2FZeonis_Sun_Dreams.jpg&imgrefurl=http%3A%2F%2Fforum.shelek.ru%2Findex.php%2Ftopic%2C26007.0.html&h=448&w=324&tbnid=p5ccOg6U2a9tlM%3A&zoom=1&docid=A-B9gHsimamd6M&ei=06SuVPLHKMe9Pe-mgNAE&tbm=isch&ved=0CE0QMygkMCQ&iact=rc&uact=3&dur=325&page=2&start=18&ndsp=24&biw=1360&bih=624' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# Файл записан
# В сообществе 30606852 участников : 18195
# Файл записан
# В сообществе 3938668 участников : 13099
# Файл записан
# В сообществе 34380444 участников : 24406
# Файл записан
# В сообществе 97005684 участников : 458
# Файл записан
# В сообществе 23062364 участников : 534
# Файл записан
# В сообществе 145630667 участников : 809
# Файл записан
# В сообществе 17836296 участников : 232
# Файл записан
# В сообществе 5640578 участников : 2041
# Файл записан
# В сообществе 35760237 участников : 6728
# Файл записан
# В сообществе 750906 участников : 393
# Файл записан
# В сообществе 38231855 участников : 20743
# Файл записан
# В сообществе 141882265 участников : 403
# Файл записан
# В сообществе 23798874 участников : None
# В сообществе 14235421 участников : 10854
# Файл записан
# В сообществе 17736722 участников : 9900
# Файл записан
# В сообществе 79397528 участников : 5201
# Файл записан
# В сообществе 139804766 участников : None
# В сообществе 34157205 участников : 155662
# Файл записан
# В сообществе 100401811 участников : 128992
# Файл записан
# В сообществе 32023708 участников : 202222
# Файл записан
# В сообществе 97392915 участников : None
# В сообществе 2822807 участников : 689
# Файл записан
# В сообществе 42036692 участников : 1468
# Файл записан
# В сообществе 114379049 участников : 235
# Файл записан
# В сообществе 83577710 участников : 1818
# Файл записан
# В сообществе 99580293 участников : 953
# C:\ProgramData\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://vk.com/app249481_55086839%20деклорации%20прав%20человека%20ООН,%20Cт.%2019:%20«Каждый%20человек%20имеет%20право%20на%20свободу%20убеждений%20и%20на%20свободное%20выражение%20их;%20это%20право%20включает%20свободу%20беспрепятственно%20придерживаться%20своих%20убеждений%20и%20свободу%20искать,%20получать%20и%20распространять%20информацию%20и%20идеи%20любыми%20средствами%20и%20независимо%20от%20государственных%20границ»;%20«Каждый%20имеет%20право%20на%20неприкосновенность%20частной%20жизни,%20личную%20и%20семейную%20тайну,%20защиту%20своей%20чести%20и%20доброго%20имени».%20%20Конституция%20РФ,%20Ст.%2023:%20«Каждый%20имеет%20право%20на%20тайну%20переписки,%20телефонных%20переговоров,%20почтовых,%20телеграфных%20и%20иных%20сообщений.%20Ограничение%20этого%20права%20допускается%20только%20на%20основании%20судебного%20решения»;%20«Сбор,%20хранение,%20использование%20и%20распространение%20информации%20о%20частной%20жизни%20лица%20без%20его%20согласия%20не%20допускаются».%20%20Конституция%20РФ,%20Ст.%2024:%20«Органы%20государственной%20власти%20и%20органы%20местного%20самоуправления,%20их%20должностные%20лица%20обязаны%20обеспечить%20каждому%20возможность%20ознакомления%20с%20документами%20и%20материалами,%20непосредственно%20затрагивающими%20его%20права%20и%20свободы,%20если%20иное%20не%20предусмотрено%20законом».%20%20Конституция%20РФ,%20Ст.%2029,%20п.%204:%20«Каждый%20имеет%20право%20свободно%20искать,%20получать,%20передавать,%20производить%20и%20распространять%20информацию%20любым%20законным%20способом».' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# Файл записан
# В сообществе 84605164 участников : 5307
# Файл записан
# В сообществе 33632563 участников : 10290
# Файл записан
# В сообществе 16543301 участников : 930
# Файл записан
# В сообществе 23240913 участников : 3575
# Файл записан
# В сообществе 22773946 участников : 2250
# Файл записан
# В сообществе 61323 участников : 62951
# Файл записан
# В сообществе 3560737 участников : 10935
# Файл записан
# В сообществе 10533171 участников : 3613
# Файл записан
# В сообществе 55333015 участников : 22106
# Файл записан
# В сообществе 50936221 участников : 959
# Файл записан
# В сообществе 86818303 участников : None
# В сообществе 47604310 участников : 315
# Файл записан
# В сообществе 1638157 участников : 2252
# Файл записан
# В сообществе 68411146 участников : 2671
# Файл записан
# В сообществе 22063893 участников : 440
# Файл записан
# В сообществе 25207919 участников : 13678
# Файл записан
# В сообществе 342730 участников : 4211
# Файл записан
# В сообществе 34124284 участников : 40118
# Файл записан
# В сообществе 51558353 участников : 33172
# Файл записан
# В сообществе 3760883 участников : 5817
# Файл записан
# В сообществе 36941146 участников : 8709
# Файл записан
